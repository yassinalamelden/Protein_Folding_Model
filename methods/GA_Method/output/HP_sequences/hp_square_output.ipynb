# %% [markdown]
# # Protein Folding using Genatic Algorithm (GA) - Square Lattice
#
# This notebook applies the **Particle Swarm Optimization (PSO)** method to protein
# folding in the `HP` model on a **Square lattice**.
#
# We benchmark multiple protein **`HP` sequences** (already converted from FASTA),
# record the **minimum energy** achieved and **runtime**, and save the results in a structured dataset.

# %%
import pandas as pd

dataset_hp = pd.read_excel(r"C:\Users\Yassin\OneDrive\Desktop\Work\Machine Learning\Machine Learning Internship\Github-1\Protein_Folding_Model-3\data\HP_dataset.xlsx")
dataset_hp.index = range(1, len(dataset_hp) + 1)
dataset_hp
# Out:
#    ID Seq  No of AA                                           Sequence
# 1       1        20                           HPHP PHHP HPPH PHHP PHPH
# 2       2        24                      HHPP HPPH PPHP PHPP HPPH PPHH
# 3       3        25                    PPHP PHHP PPPH HPPP PHHP PPPH H
# 4       4        36       PPPH HPPH HPPP PPHH HHHH HPPH HPPP PHHP PHPP
# 5       5        48  PPHP PHHP PHHP PPPP HHHH HHHH HHPP PPPP HHPP H...
# 6       6        50  HHPH PHPH PHHH HPHP PPHP PPHP PPPH PPPH PPPH P...
# 7       7        60  PPHH HPHH HHHH HHPP PHHH HHHH HHHP HPPP HHHH H...
# 8       8        64  HHHH HHHH HHHH PHPH PPHH PPHH PPHP PHHP PHHP P...
# 9       9        85  HHHH PPPP HHHH HHHH HHHH PPPP PPHH HHHH HHHH H...

# %% [markdown]
# ### **Id 1 Sequence**

# %%
import time
from genatic_algorithm_method import square_genetic_algorithm, visualize_fold

protein_id = "1"
hp_sequence = "HPHPPHHPHPPHPHHPPHPH"

lattice_type = "square"  

start_time = time.time()

if lattice_type == "square":
    min_energy, best_coords = square_genetic_algorithm(hp_sequence, generations=5000, pop_size=200)
elif lattice_type == "triangular":
    min_energy, best_coords = trianguler_genetic_algorithm(hp_sequence, generations=5000, pop_size=500)
elif lattice_type == "cubic":
    min_energy, best_coords = genetic_algorithm_3d(hp_sequence, generations=5000, pop_size=200)
else:
    raise ValueError("Invalid lattice type selected.")

end_time = time.time()

runtime = round((end_time - start_time) / 60, 2)

# Print results
print(f"Protein Id: {protein_id}")
print(f"HP Sequence: {hp_sequence}")
print(f"Length: {len(hp_sequence)}")
print(f"Minimum Energy: {min_energy}")
print(f"Runtime (min): {runtime}")

# Visualize folding
visualize_fold(hp_sequence, best_coords, min_energy)
# Out:
# Protein Id: 1
# HP Sequence: HPHPPHHPHPPHPHHPPHPH
# Length: 20
# Minimum Energy: -9
# Runtime (min): 0.31

# %% [markdown]
# ### **Id 2 Sequence**

# %%
protein_id = "2"
hp_sequence = "HHPPHPPHPPHPPHPPHPPHPPHH"

lattice_type = "square"  

start_time = time.time()

if lattice_type == "square":
    min_energy, best_coords = square_genetic_algorithm(hp_sequence, generations=5000, pop_size=200)
elif lattice_type == "triangular":
    min_energy, best_coords = trianguler_genetic_algorithm(hp_sequence, generations=5000, pop_size=500)
elif lattice_type == "cubic":
    min_energy, best_coords = genetic_algorithm_3d(hp_sequence, generations=5000, pop_size=200)
else:
    raise ValueError("Invalid lattice type selected.")

end_time = time.time()

runtime = round((end_time - start_time) / 60, 2)

# Print results
print(f"Protein Id: {protein_id}")
print(f"HP Sequence: {hp_sequence}")
print(f"Length: {len(hp_sequence)}")
print(f"Minimum Energy: {min_energy}")
print(f"Runtime (min): {runtime}")

# Visualize folding
visualize_fold(hp_sequence, best_coords, min_energy)
# Out:
# Protein Id: 2
# HP Sequence: HHPPHPPHPPHPPHPPHPPHPPHH
# Length: 24
# Minimum Energy: -9
# Runtime (min): 0.36

# %% [markdown]
# ### **Id 3 Sequence**

# %%
protein_id = "3"
hp_sequence = "PPHPPHHPPPPHHPPPPHHPPPPHH"

lattice_type = "square"  

start_time = time.time()

if lattice_type == "square":
    min_energy, best_coords = square_genetic_algorithm(hp_sequence, generations=5000, pop_size=200)
elif lattice_type == "triangular":
    min_energy, best_coords = trianguler_genetic_algorithm(hp_sequence, generations=5000, pop_size=500)
elif lattice_type == "cubic":
    min_energy, best_coords = genetic_algorithm_3d(hp_sequence, generations=5000, pop_size=200)
else:
    raise ValueError("Invalid lattice type selected.")

end_time = time.time()

runtime = round((end_time - start_time) / 60, 2)

# Print results
print(f"Protein Id: {protein_id}")
print(f"HP Sequence: {hp_sequence}")
print(f"Length: {len(hp_sequence)}")
print(f"Minimum Energy: {min_energy}")
print(f"Runtime (min): {runtime}")

# Visualize folding
visualize_fold(hp_sequence, best_coords, min_energy)
# Out:
# Protein Id: 3
# HP Sequence: PPHPPHHPPPPHHPPPPHHPPPPHH
# Length: 25
# Minimum Energy: -8
# Runtime (min): 0.34

# %% [markdown]
# ### **Id 4 Sequence**

# %%
protein_id = "4"
hp_sequence = "PPPHHPPHHPPPPPHHHHHHHPPHHPPPPHHPPHPP"

lattice_type = "square"  

start_time = time.time()

if lattice_type == "square":
    min_energy, best_coords = square_genetic_algorithm(hp_sequence, generations=5000, pop_size=200)
elif lattice_type == "triangular":
    min_energy, best_coords = trianguler_genetic_algorithm(hp_sequence, generations=5000, pop_size=500)
elif lattice_type == "cubic":
    min_energy, best_coords = genetic_algorithm_3d(hp_sequence, generations=5000, pop_size=200)
else:
    raise ValueError("Invalid lattice type selected.")

end_time = time.time()

runtime = round((end_time - start_time) / 60, 2)

# Print results
print(f"Protein Id: {protein_id}")
print(f"HP Sequence: {hp_sequence}")
print(f"Length: {len(hp_sequence)}")
print(f"Minimum Energy: {min_energy}")
print(f"Runtime (min): {runtime}")

# Visualize folding
visualize_fold(hp_sequence, best_coords, min_energy)
# Out:
# Protein Id: 4
# HP Sequence: PPPHHPPHHPPPPPHHHHHHHPPHHPPPPHHPPHPP
# Length: 36
# Minimum Energy: -13
# Runtime (min): 0.45

# %% [markdown]
# ### **Id 5 Sequence**

# %%
protein_id = "5"
hp_sequence = "PPHPPHHPPHHPPPPPHHHHHHHHHHPPPPPPHHPPHHPPHPPHHHHH"

lattice_type = "square"  

start_time = time.time()

if lattice_type == "square":
    min_energy, best_coords = square_genetic_algorithm(hp_sequence, generations=5000, pop_size=200)
elif lattice_type == "triangular":
    min_energy, best_coords = trianguler_genetic_algorithm(hp_sequence, generations=5000, pop_size=500)
elif lattice_type == "cubic":
    min_energy, best_coords = genetic_algorithm_3d(hp_sequence, generations=5000, pop_size=200)
else:
    raise ValueError("Invalid lattice type selected.")

end_time = time.time()

runtime = round((end_time - start_time) / 60, 2)

# Print results
print(f"Protein Id: {protein_id}")
print(f"HP Sequence: {hp_sequence}")
print(f"Length: {len(hp_sequence)}")
print(f"Minimum Energy: {min_energy}")
print(f"Runtime (min): {runtime}")

# Visualize folding
visualize_fold(hp_sequence, best_coords, min_energy)
# Out:
# Protein Id: 5
# HP Sequence: PPHPPHHPPHHPPPPPHHHHHHHHHHPPPPPPHHPPHHPPHPPHHHHH
# Length: 48
# Minimum Energy: -19
# Runtime (min): 0.62

# %% [markdown]
# ### **Id 6 Sequence**

# %%
protein_id = "6"
hp_sequence = "HHPHPHPHPHHHHPHPPPHPPPHPPPPHPPPHPPPHPHHHHPHPHPHPHH"

lattice_type = "square"  

start_time = time.time()

if lattice_type == "square":
    min_energy, best_coords = square_genetic_algorithm(hp_sequence, generations=5000, pop_size=200)
elif lattice_type == "triangular":
    min_energy, best_coords = trianguler_genetic_algorithm(hp_sequence, generations=5000, pop_size=500)
elif lattice_type == "cubic":
    min_energy, best_coords = genetic_algorithm_3d(hp_sequence, generations=5000, pop_size=200)
else:
    raise ValueError("Invalid lattice type selected.")

end_time = time.time()

runtime = round((end_time - start_time) / 60, 2)

# Print results
print(f"Protein Id: {protein_id}")
print(f"HP Sequence: {hp_sequence}")
print(f"Length: {len(hp_sequence)}")
print(f"Minimum Energy: {min_energy}")
print(f"Runtime (min): {runtime}")

# Visualize folding
visualize_fold(hp_sequence, best_coords, min_energy)
# Out:
# Protein Id: 6
# HP Sequence: HHPHPHPHPHHHHPHPPPHPPPHPPPPHPPPHPPPHPHHHHPHPHPHPHH
# Length: 50
# Minimum Energy: -20
# Runtime (min): 0.61

# %% [markdown]
# ### **Id 7 Sequence**

# %%
protein_id = "7"
hp_sequence = "PPHHHPHHHHHHHHPPPHHHHHHHHHHPHPPPHHHHHHHHHHHHPPPPHHHHHHPHHPHP"

lattice_type = "square"  

start_time = time.time()

if lattice_type == "square":
    min_energy, best_coords = square_genetic_algorithm(hp_sequence, generations=5000, pop_size=200)
elif lattice_type == "triangular":
    min_energy, best_coords = trianguler_genetic_algorithm(hp_sequence, generations=5000, pop_size=500)
elif lattice_type == "cubic":
    min_energy, best_coords = genetic_algorithm_3d(hp_sequence, generations=5000, pop_size=200)
else:
    raise ValueError("Invalid lattice type selected.")

end_time = time.time()

runtime = round((end_time - start_time) / 60, 2)

# Print results
print(f"Protein Id: {protein_id}")
print(f"HP Sequence: {hp_sequence}")
print(f"Length: {len(hp_sequence)}")
print(f"Minimum Energy: {min_energy}")
print(f"Runtime (min): {runtime}")

# Visualize folding
visualize_fold(hp_sequence, best_coords, min_energy)
# Out:
# Protein Id: 7
# HP Sequence: PPHHHPHHHHHHHHPPPHHHHHHHHHHPHPPPHHHHHHHHHHHHPPPPHHHHHHPHHPHP
# Length: 60
# Minimum Energy: -30
# Runtime (min): 0.73

# %% [markdown]
# ### **Id 8 Sequence**

# %%
protein_id = "8"
hp_sequence = "HHHHHHHHHHHHPHPHPPHHPPHHPPHPPHHPPHHPPHPPHHPPHHPPHPHPHHHHHHHHHHHH"

lattice_type = "square"  

start_time = time.time()

if lattice_type == "square":
    min_energy, best_coords = square_genetic_algorithm(hp_sequence, generations=5000, pop_size=200)
elif lattice_type == "triangular":
    min_energy, best_coords = trianguler_genetic_algorithm(hp_sequence, generations=5000, pop_size=500)
elif lattice_type == "cubic":
    min_energy, best_coords = genetic_algorithm_3d(hp_sequence, generations=5000, pop_size=200)
else:
    raise ValueError("Invalid lattice type selected.")

end_time = time.time()

runtime = round((end_time - start_time) / 60, 2)

# Print results
print(f"Protein Id: {protein_id}")
print(f"HP Sequence: {hp_sequence}")
print(f"Length: {len(hp_sequence)}")
print(f"Minimum Energy: {min_energy}")
print(f"Runtime (min): {runtime}")

# Visualize folding
visualize_fold(hp_sequence, best_coords, min_energy)
# Out:
# Protein Id: 8
# HP Sequence: HHHHHHHHHHHHPHPHPPHHPPHHPPHPPHHPPHHPPHPPHHPPHHPPHPHPHHHHHHHHHHHH
# Length: 64
# Minimum Energy: -34
# Runtime (min): 0.8

# %% [markdown]
# ### **Id 9 Sequence**

# %%
protein_id = "9"
hp_sequence = "HHHHPPPPHHHHHHHHHHHHPPPPPPHHHHHHHHHHHHPPPHHHHHHHHHHHHPPPHHHHHHHHHHHHPPPHPPHHPPHHPPHPH"

lattice_type = "square"  

start_time = time.time()

if lattice_type == "square":
    min_energy, best_coords = square_genetic_algorithm(hp_sequence, generations=5000, pop_size=200)
elif lattice_type == "triangular":
    min_energy, best_coords = trianguler_genetic_algorithm(hp_sequence, generations=5000, pop_size=500)
elif lattice_type == "cubic":
    min_energy, best_coords = genetic_algorithm_3d(hp_sequence, generations=5000, pop_size=200)
else:
    raise ValueError("Invalid lattice type selected.")

end_time = time.time()

runtime = round((end_time - start_time) / 60, 2)

# Print results
print(f"Protein Id: {protein_id}")
print(f"HP Sequence: {hp_sequence}")
print(f"Length: {len(hp_sequence)}")
print(f"Minimum Energy: {min_energy}")
print(f"Runtime (min): {runtime}")

# Visualize folding
visualize_fold(hp_sequence, best_coords, min_energy)
# Out:
# Protein Id: 9
# HP Sequence: HHHHPPPPHHHHHHHHHHHHPPPPPPHHHHHHHHHHHHPPPHHHHHHHHHHHHPPPHHHHHHHHHHHHPPPHPPHHPPHHPPHPH
# Length: 85
# Minimum Energy: -38
# Runtime (min): 0.88

# %% [markdown]
# ## 📊 Results: GA Method (Square Lattice)
#
# The table below summarizes the performance of the **Genatic Algorithm (GA)** algorithm applied to the `HP` protein sequences dataset.
# For each protein sequence, we record:

# %%
square_data = [
    {"Protein Id": "1", "HP Sequence": "HPHPPHHPHPPHPHHPPHPH", "Length": 20, "Minimum Energy": -9, "Runtime (min)": 0.31},
    {"Protein Id": "2", "HP Sequence": "HHPPHPPHPPHPPHPPHPPHPPHH", "Length": 24, "Minimum Energy": -9, "Runtime (min)": 0.36},
    {"Protein Id": "3", "HP Sequence": "PPHPPHHPPPPHHPPPPHHPPPPHH", "Length": 25, "Minimum Energy": -8, "Runtime (min)": 0.34},
    {"Protein Id": "4", "HP Sequence": "PPPHHPPHHPPPPPHHHHHHHPPHHPPPPHHPPHPP", "Length": 36, "Minimum Energy": -13, "Runtime (min)": 0.45},
    {"Protein Id": "5", "HP Sequence": "PPHPPHHPPHHPPPPPHHHHHHHHHHPPPPPPHHPPHHPPHPPHHHHH", "Length": 48, "Minimum Energy": -19, "Runtime (min)": 0.62},
    {"Protein Id": "6", "HP Sequence": "HHPHPHPHPHHHHPHPPPHPPPHPPPPHPPPHPPPHPHHHHPHPHPHPHH", "Length": 50, "Minimum Energy": -20, "Runtime (min)": 0.61},
    {"Protein Id": "7", "HP Sequence": "PPHHHPHHHHHHHHPPPHHHHHHHHHHPHPPPHHHHHHHHHHHHPPPPHHHHHHPHHPHP", "Length": 60, "Minimum Energy": -30, "Runtime (min)": 0.73},
    {"Protein Id": "8", "HP Sequence": "HHHHHHHHHHHHPHPHPPHHPPHHPPHPPHHPPHHPPHPPHHPPHHPPHPHPHHHHHHHHHHHH", "Length": 64, "Minimum Energy": -34, "Runtime (min)": 0.80},
    {"Protein Id": "9", "HP Sequence": "HHHHPPPPHHHHHHHHHHHHPPPPPPHHHHHHHHHHHHPPPHHHHHHHHHHHHPPPHHHHHHHHHHHHPPPHPPHHPPHHPPHPH", "Length": 85, "Minimum Energy": -38, "Runtime (min)": 0.88},
]

dataset_square = pd.DataFrame(square_data)
dataset_square.index = range(1, len(dataset_square) + 1)
dataset_square
# Out:
#   Protein Id                                        HP Sequence  Length  \
# 1          1                               HPHPPHHPHPPHPHHPPHPH      20
# 2          2                           HHPPHPPHPPHPPHPPHPPHPPHH      24
# 3          3                          PPHPPHHPPPPHHPPPPHHPPPPHH      25
# 4          4               PPPHHPPHHPPPPPHHHHHHHPPHHPPPPHHPPHPP      36
# 5          5   PPHPPHHPPHHPPPPPHHHHHHHHHHPPPPPPHHPPHHPPHPPHHHHH      48
# 6          6  HHPHPHPHPHHHHPHPPPHPPPHPPPPHPPPHPPPHPHHHHPHPHP...      50
# 7          7  PPHHHPHHHHHHHHPPPHHHHHHHHHHPHPPPHHHHHHHHHHHHPP...      60
# 8          8  HHHHHHHHHHHHPHPHPPHHPPHHPPHPPHHPPHHPPHPPHHPPHH...      64
# 9          9  HHHHPPPPHHHHHHHHHHHHPPPPPPHHHHHHHHHHHHPPPHHHHH...      85
#
#    Minimum Energy  Runtime (min)
# 1              -9           0.31
# 2              -9           0.36
# 3              -8           0.34
# 4             -13           0.45
# 5             -19           0.62
# 6             -20           0.61
# 7             -30           0.73
# 8             -34           0.80
# 9             -38           0.88
